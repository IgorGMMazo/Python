# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns

# %%
"""
A função read do pandas lê diferentes tipos de arquivos ( Ex.: read_json , read_execel...)
"""
df = pd.read_csv()
df.head()       #Mostra a 5 primeiras linhas do dataframe 
df.tail()       #Mostra as últimas 5 linhas
df.info()       #resumo técnico ( quantas linhas , colunas , tipos , etc)
df.desribe()    #Gera estastíticas descritivas para valores numéricos
df.shape()      #Retorna uma tupla
df.groupby()    #Divide o dataframe em grupos para depois fazer operações , como o GROUP BY do SQL
d
